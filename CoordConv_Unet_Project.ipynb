# %% [markdown]
# <a href="https://colab.research.google.com/github/ncpitrsb/Brain-MRI-segmentation/blob/main/CoordConv_Unet_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This code has reference from:
#
# Dataset: https://www.kaggle.com/mateuszbuda/lgg-mri-segmentation
#
# Most part of code: https://www.kaggle.com/mateuszbuda/lgg-mri-segmentation
#
# Research Paper: CoordConv-Unet: Investigating CoordConv for Organ Segmentation
# https://www.sciencedirect.com/science/article/pii/S1959031821000324
#
# CoordConv Model: https://github.com/tchaton/CoordConv-keras

# %% [markdown]
# # **Prepare Data**

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

import cv2
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Flatten, Softmax
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

import matplotlib.pyplot as plt

from keras.layers import Input, Conv2D, Flatten, Softmax
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam

# %%
#Set Parameters
im_width = 256
im_height = 256

# %%
! pip install -q kaggle

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-0c912c48-f1fa-4817-9e51-030b1695dc34" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c912c48-f1fa-4817-9e51-030b1695dc34">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"nutthaponp","key":"cff9285f6202578cdbc4a6488b76d91c"}'}

# %%
 ! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              227KB  2021-05-05 14:54:57           4331
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-04-28 17:03:01           2500
# promptcloud/careerbuilder-job-listing-2020                  Careerbuilder Job Listing 2020                     42MB  2021-03-05 06:59:52            582
# mathurinache/twitter-edge-nodes                             Twitter Edge Nodes                                342MB  2021-03-08 06:43:04            266
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   1GB  2021-02-18 10:08:27           1530
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19            876
# alsgroup/end-als                                            End ALS Kaggle Challenge                           12GB  2021-04-08 12:16:37            579
# nickuzmenkov/nih-chest-xrays-tfrecords                      NIH Chest X-rays TFRecords                         11GB  2021-03-09 04:49:23            397
# simiotic/github-code-snippets                               GitHub Code Snippets                                7GB  2021-03-03 11:34:39             94
# fatiimaezzahra/famous-iconic-women                          Famous Iconic Women                               838MB  2021-02-28 14:56:00            491
# coloradokb/dandelionimages                                  DandelionImages                                     4GB  2021-02-19 20:03:47            227
tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_70.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_70_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_71.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_71_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_72.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_72_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_73.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_73_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_74.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_74_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_75.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_75_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_76.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_76_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_77.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_77_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_78.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_78_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_79.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_79_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_7_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_8.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_80.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_80_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_81.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_81_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_82.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_82_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_83.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_83_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_84.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_84_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_85.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_85_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_86.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_86_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_87.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_87_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_88.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_88_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_8_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_9.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_9_mask.tif
#   inflating: train/lgg-mri-segmentation/kaggle_3m/data.csv

# %%
train_files = []
mask_files = glob('/content/train/lgg-mri-segmentation/kaggle_3m/*/*_mask*')

for i in mask_files:
    train_files.append(i.replace('_mask',''))

print(train_files[:10])
print(mask_files[:10])
# Out:
# ['/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_10.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_4.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_19.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_14.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_1.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_2.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_21.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_16.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_17.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_13.tif']
# ['/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_10_mask.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_4_mask.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_19_mask.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_14_mask.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_1_mask.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_2_mask.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_21_mask.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_16_mask.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_17_mask.tif', '/content/train/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7855_19951020/TCGA_HT_7855_19951020_13_mask.tif']

# %%
#Lets plot some samples
rows,cols=3,3
fig=plt.figure(figsize=(10,10))
for i in range(1,rows*cols+1):
    fig.add_subplot(rows,cols,i)
    img_path=train_files[i]
    msk_path=mask_files[i]
    img=cv2.imread(img_path)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    msk=cv2.imread(msk_path)
    plt.imshow(img)
    plt.imshow(msk,alpha=0.4)
plt.show()

# %%
df = pd.DataFrame(data={"filename": train_files, 'mask' : mask_files})
df_train, df_test = train_test_split(df,test_size = 0.1)
df_train, df_val = train_test_split(df_train,test_size = 0.2)
print(df_train.values.shape)
print(df_val.values.shape)
print(df_test.values.shape)
# Out:
# (2828, 2)
# (708, 2)
# (393, 2)

# %%
# From: https://github.com/zhixuhao/unet/blob/master/data.py
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):
    '''
    can generate image and mask at the same time use the same seed for
    image_datagen and mask_datagen to ensure the transformation for image
    and mask is the same if you want to visualize the results of generator,
    set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "filename",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
smooth=100

def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    And=K.sum(y_truef* y_predf)
    return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def jac_distance(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)

    return - iou(y_true, y_pred)

# %% [markdown]
# # **Create CoordConv2D Class**

# %%
from keras.engine import Layer
from keras.layers import InputSpec
from tensorflow.keras.layers import *
from tensorflow.python.keras.utils import conv_utils


class CoordConv2D(Layer):

    def __init__(self, filters,
                 kernel_size,
                 strides=1,
                 padding='valid',
                 data_format=None,
                 dilation_rate=1,
                 activation=None,
                 use_bias=True,
                 kernel_initializer='glorot_uniform',
                 bias_initializer='zeros',
                 kernel_regularizer=None,
                 bias_regularizer=None,
                 activity_regularizer=None,
                 kernel_constraint=None,
                 bias_constraint=None,
                 rank=2,
                 with_r=False,
                 **kwargs):
        super(CoordConv2D, self).__init__(**kwargs)
        self.filters = filters
        self.kernel_size = conv_utils.normalize_tuple(kernel_size, rank, 'kernel_size')
        self.strides = conv_utils.normalize_tuple(strides, rank, 'strides')
        self.padding = conv_utils.normalize_padding(padding)
        self.data_format = conv_utils.normalize_data_format(data_format)
        self.dilation_rate = conv_utils.normalize_tuple(dilation_rate, rank, 'dilation_rate')
        self.activation = tf.keras.activations.get(activation)
        self.use_bias = use_bias
        self.kernel_initializer = tf.keras.initializers.get(kernel_initializer)
        self.bias_initializer = tf.keras.initializers.get(bias_initializer)
        self.kernel_regularizer = tf.keras.regularizers.get(kernel_regularizer)
        self.bias_regularizer = tf.keras.regularizers.get(bias_regularizer)
        self.activity_regularizer = tf.keras.regularizers.get(activity_regularizer)
        self.kernel_constraint = tf.keras.constraints.get(kernel_constraint)
        self.bias_constraint = tf.keras.constraints.get(bias_constraint)
        self.input_spec = InputSpec(ndim=rank + 2)
        self.rank=rank
        self.with_r = with_r
        
    def build(self, input_shape):
        if self.data_format == 'channels_first':
            channel_axis = 1
        else:
            channel_axis = -1
        if input_shape[channel_axis] is None:
            raise ValueError('The channel dimension of the inputs '
                             'should be defined. Found `None`.')
        input_dim = input_shape[channel_axis]
        shift=2
        if self.with_r:
            shift+=1
        kernel_shape = self.kernel_size + (input_dim+shift, self.filters)
        print(kernel_shape)
        self.kernel = self.add_weight(shape=kernel_shape,
                                      initializer=self.kernel_initializer,
                                      name='kernel',
                                      regularizer=self.kernel_regularizer,
                                      constraint=self.kernel_constraint)
        if self.use_bias:
            self.bias = self.add_weight(shape=(self.filters,),
                                        initializer=self.bias_initializer,
                                        name='bias',
                                        regularizer=self.bias_regularizer,
                                        constraint=self.bias_constraint)
        else:
            self.bias = None
        # Set input spec.
        self.input_spec = InputSpec(ndim=self.rank + 2,
                                    axes={channel_axis: input_dim})
        self.built = True
        
    
    def addCoord(self, inputs):
        
        shape = tf.shape(inputs)
        batch_size_tensor, x_dim, y_dim, c = shape[0], shape[1], shape[2], shape[3]
        
        xx_ones = tf.ones([batch_size_tensor, x_dim], dtype=tf.float32)
        
        xx_ones = tf.expand_dims(xx_ones, axis=-1)
        
        xx_range = tf.tile(tf.expand_dims(tf.range(x_dim), 0), [batch_size_tensor, 1])
        xx_range = tf.cast(xx_range, tf.float32)
        xx_range = tf.expand_dims(xx_range, axis=1)
        
        xx_channel = tf.matmul(xx_ones, xx_range)
        xx_channel = tf.expand_dims(xx_channel, axis=-1)
              
        xx_channel = xx_channel / tf.cast(x_dim - 1, tf.float32)
        
        xx_channel = xx_channel*2 - 1
        
        ret = tf.concat([inputs, xx_channel, tf.transpose(xx_channel, (0, 2, 1, 3))], axis=-1)
        
        if self.with_r:
            
            rr = tf.sqrt( tf.square(xx_channel - .5) + tf.square(  tf.transpose(xx_channel) - .5))
            ret = tf.concat([ret, rr], axis=-1)
        return ret

    def compute_output_shape(self, input_shape):
        if self.data_format == 'channels_last':
            space = input_shape[1:-1]
            new_space = []
            for i in range(len(space)):
                new_dim = conv_utils.conv_output_length(
                    space[i],
                    self.kernel_size[i],
                    padding=self.padding,
                    stride=self.strides[i],
                    dilation=self.dilation_rate[i])
                new_space.append(new_dim)
            return (input_shape[0],) + tuple(new_space) + (self.filters,)
        if self.data_format == 'channels_first':
            space = input_shape[2:]
            new_space = []
            for i in range(len(space)):
                new_dim = conv_utils.conv_output_length(
                    space[i],
                    self.kernel_size[i],
                    padding=self.padding,
                    stride=self.strides[i],
                    dilation=self.dilation_rate[i])
                new_space.append(new_dim)
        return (input_shape[0], self.filters) + tuple(new_space)
        
    def call(self, inputs):
        #Coordination
        
        inputs = self.addCoord(inputs)
        
        if self.rank == 2:
            outputs = K.conv2d(
                inputs,
                self.kernel,
                strides=self.strides,
                padding=self.padding,
                data_format=self.data_format,
                dilation_rate=self.dilation_rate)
        else:
            raise Exception('rank should be two for now')
            
        if self.use_bias:
            outputs += self.bias
            
        if self.activation is not None:
            return self.activation(outputs)
        return outputs


    def get_config(self):
        config = {
            'rank': self.rank,
            'filters': self.filters,
            'kernel_size': self.kernel_size,
            'strides': self.strides,
            'padding': self.padding,
            'data_format': self.data_format,
            'dilation_rate': self.dilation_rate,
            'activation': tf.keras.activations.serialize(self.activation),
            'use_bias': self.use_bias,
            'kernel_initializer': tf.keras.initializers.serialize(self.kernel_initializer),
            'bias_initializer': tf.keras.initializers.serialize(self.bias_initializer),
            'kernel_regularizer': tf.keras.regularizers.serialize(self.kernel_regularizer),
            'bias_regularizer': tf.keras.regularizers.serialize(self.bias_regularizer),
            'activity_regularizer': tf.keras.regularizers.serialize(self.activity_regularizer),
            'kernel_constraint': tf.keras.constraints.serialize(self.kernel_constraint),
            'bias_constraint': tf.keras.constraints.serialize(self.bias_constraint)
        }
        base_config = super(CoordConv2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# # **Generate Model Initializer**

# %% [markdown]
# ## Unet

# %%
def unet(input_size=(256,256,3)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(64, (3, 3), padding='same')(inputs)
    bn1 = Activation('relu')(conv1)
    conv1 = Conv2D(64, (3, 3), padding='same')(bn1)
    bn1 = BatchNormalization(axis=3)(conv1)
    bn1 = Activation('relu')(bn1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(bn1)

    conv2 = Conv2D(128, (3, 3), padding='same')(pool1)
    bn2 = Activation('relu')(conv2)
    conv2 = Conv2D(128, (3, 3), padding='same')(bn2)
    bn2 = BatchNormalization(axis=3)(conv2)
    bn2 = Activation('relu')(bn2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(bn2)

    conv3 = Conv2D(256, (3, 3), padding='same')(pool2)
    bn3 = Activation('relu')(conv3)
    conv3 = Conv2D(256, (3, 3), padding='same')(bn3)
    bn3 = BatchNormalization(axis=3)(conv3)
    bn3 = Activation('relu')(bn3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(bn3)

    conv4 = Conv2D(512, (3, 3), padding='same')(pool3)
    bn4 = Activation('relu')(conv4)
    conv4 = Conv2D(512, (3, 3), padding='same')(bn4)
    bn4 = BatchNormalization(axis=3)(conv4)
    bn4 = Activation('relu')(bn4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(bn4)

    conv5 = Conv2D(1024, (3, 3), padding='same')(pool4)
    bn5 = Activation('relu')(conv5)
    conv5 = Conv2D(1024, (3, 3), padding='same')(bn5)
    bn5 = BatchNormalization(axis=3)(conv5)
    bn5 = Activation('relu')(bn5)

    up6 = concatenate([Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(bn5), conv4], axis=3)
    conv6 = Conv2D(512, (3, 3), padding='same')(up6)
    bn6 = Activation('relu')(conv6)
    conv6 = Conv2D(512, (3, 3), padding='same')(bn6)
    bn6 = BatchNormalization(axis=3)(conv6)
    bn6 = Activation('relu')(bn6)

    up7 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(bn6), conv3], axis=3)
    conv7 = Conv2D(256, (3, 3), padding='same')(up7)
    bn7 = Activation('relu')(conv7)
    conv7 = Conv2D(256, (3, 3), padding='same')(bn7)
    bn7 = BatchNormalization(axis=3)(conv7)
    bn7 = Activation('relu')(bn7)

    up8 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(bn7), conv2], axis=3)
    conv8 = Conv2D(128, (3, 3), padding='same')(up8)
    bn8 = Activation('relu')(conv8)
    conv8 = Conv2D(128, (3, 3), padding='same')(bn8)
    bn8 = BatchNormalization(axis=3)(conv8)
    bn8 = Activation('relu')(bn8)

    up9 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(bn8), conv1], axis=3)
    conv9 = Conv2D(64, (3, 3), padding='same')(up9)
    bn9 = Activation('relu')(conv9)
    conv9 = Conv2D(64, (3, 3), padding='same')(bn9)
    bn9 = BatchNormalization(axis=3)(conv9)
    bn9 = Activation('relu')(bn9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(bn9)

    return Model(inputs=[inputs], outputs=[conv10])

# %% [markdown]
# ## CoordConv2D

# %%
def coord_conv_unet(input_size=(256,256,3)):
    inputs = Input(input_size)
    
    conv1 = CoordConv2D(64, (3, 3), padding='same')(inputs)
    bn1 = Activation('relu')(conv1)
    conv1 = CoordConv2D(64, (3, 3), padding='same')(bn1)
    bn1 = BatchNormalization(axis=3)(conv1)
    bn1 = Activation('relu')(bn1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(bn1)

    conv2 = CoordConv2D(128, (3, 3), padding='same')(pool1)
    bn2 = Activation('relu')(conv2)
    conv2 = CoordConv2D(128, (3, 3), padding='same')(bn2)
    bn2 = BatchNormalization(axis=3)(conv2)
    bn2 = Activation('relu')(bn2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(bn2)

    conv3 = CoordConv2D(256, (3, 3), padding='same')(pool2)
    bn3 = Activation('relu')(conv3)
    conv3 = CoordConv2D(256, (3, 3), padding='same')(bn3)
    bn3 = BatchNormalization(axis=3)(conv3)
    bn3 = Activation('relu')(bn3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(bn3)

    conv4 = CoordConv2D(512, (3, 3), padding='same')(pool3)
    bn4 = Activation('relu')(conv4)
    conv4 = CoordConv2D(512, (3, 3), padding='same')(bn4)
    bn4 = BatchNormalization(axis=3)(conv4)
    bn4 = Activation('relu')(bn4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(bn4)

    conv5 = CoordConv2D(1024, (3, 3), padding='same')(pool4)
    bn5 = Activation('relu')(conv5)
    conv5 = CoordConv2D(1024, (3, 3), padding='same')(bn5)
    bn5 = BatchNormalization(axis=3)(conv5)
    bn5 = Activation('relu')(bn5)

    up6 = concatenate([Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(bn5), conv4], axis=3)
    conv6 = CoordConv2D(512, (3, 3), padding='same')(up6)
    bn6 = Activation('relu')(conv6)
    conv6 = CoordConv2D(512, (3, 3), padding='same')(bn6)
    bn6 = BatchNormalization(axis=3)(conv6)
    bn6 = Activation('relu')(bn6)

    up7 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(bn6), conv3], axis=3)
    conv7 = CoordConv2D(256, (3, 3), padding='same')(up7)
    bn7 = Activation('relu')(conv7)
    conv7 = CoordConv2D(256, (3, 3), padding='same')(bn7)
    bn7 = BatchNormalization(axis=3)(conv7)
    bn7 = Activation('relu')(bn7)

    up8 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(bn7), conv2], axis=3)
    conv8 = CoordConv2D(128, (3, 3), padding='same')(up8)
    bn8 = Activation('relu')(conv8)
    conv8 = CoordConv2D(128, (3, 3), padding='same')(bn8)
    bn8 = BatchNormalization(axis=3)(conv8)
    bn8 = Activation('relu')(bn8)

    up9 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(bn8), conv1], axis=3)
    conv9 = CoordConv2D(64, (3, 3), padding='same')(up9)
    bn9 = Activation('relu')(conv9)
    conv9 = CoordConv2D(64, (3, 3), padding='same')(bn9)
    bn9 = BatchNormalization(axis=3)(conv9)
    bn9 = Activation('relu')(bn9)

    conv10 = CoordConv2D(1, (1, 1), activation='sigmoid')(bn9)

    return Model(inputs=[inputs], outputs=[conv10])

# %% [markdown]
# # **Train and Evaluate Model**

# %%
model = coord_conv_unet()
model.summary()

# %%
EPOCHS = 100
BATCH_SIZE = 32
learning_rate = 1e-4

# %%
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')
train_gen = train_generator(df_train, BATCH_SIZE,
                                train_generator_args,
                                target_size=(im_height, im_width))
    
test_gener = train_generator(df_val, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))
    
model = coord_conv_unet(input_size=(im_height, im_width, 3))



decay_rate = learning_rate / EPOCHS
opt = Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=None, decay=decay_rate, amsgrad=False)
model.compile(optimizer=opt, loss=dice_coef_loss, metrics=["binary_accuracy", iou, dice_coef])

callbacks = [ModelCheckpoint('unet_brain_mri_seg.hdf5', verbose=1, save_best_only=True)]

history = model.fit(train_gen,
                    steps_per_epoch=len(df_train) / BATCH_SIZE, 
                    epochs=EPOCHS, 
                    callbacks=callbacks,
                    validation_data = test_gener,
                    validation_steps=len(df_val) / BATCH_SIZE,
                    verbose = 2)
# Out:
# (3, 3, 5, 64)
# (3, 3, 66, 64)
# (3, 3, 66, 128)
# (3, 3, 130, 128)
# (3, 3, 130, 256)
# (3, 3, 258, 256)
# (3, 3, 258, 512)
# (3, 3, 514, 512)
# (3, 3, 514, 1024)
# (3, 3, 1026, 1024)
# (3, 3, 1026, 512)
# (3, 3, 514, 512)
# (3, 3, 514, 256)
# (3, 3, 258, 256)
# (3, 3, 258, 128)
# (3, 3, 130, 128)
# (3, 3, 130, 64)
# (3, 3, 66, 64)
# (1, 1, 66, 1)
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# Epoch 1/100
# Found 708 validated image filenames.
# Found 708 validated image filenames.
# 88/88 - 271s - loss: -9.2732e-02 - binary_accuracy: 0.8913 - iou: 0.0497 - dice_coef: 0.0936 - val_loss: -3.1928e-02 - val_binary_accuracy: 0.8930 - val_iou: 0.0172 - val_dice_coef: 0.0335
#
# Epoch 00001: val_loss improved from inf to -0.03193, saving model to unet_brain_mri_seg.hdf5
# Epoch 2/100
# 88/88 - 198s - loss: -1.6845e-01 - binary_accuracy: 0.9813 - iou: 0.0932 - dice_coef: 0.1687 - val_loss: -3.5165e-02 - val_binary_accuracy: 0.9901 - val_iou: 0.0177 - val_dice_coef: 0.0342
#
# Epoch 00002: val_loss improved from -0.03193 to -0.03516, saving model to unet_brain_mri_seg.hdf5
# Epoch 3/100
# 88/88 - 198s - loss: -2.1638e-01 - binary_accuracy: 0.9869 - iou: 0.1224 - dice_coef: 0.2151 - val_loss: -9.3379e-02 - val_binary_accuracy: 0.9917 - val_iou: 0.0488 - val_dice_coef: 0.0910
#
# Epoch 00003: val_loss improved from -0.03516 to -0.09338, saving model to unet_brain_mri_seg.hdf5
# Epoch 4/100
# 88/88 - 198s - loss: -2.6166e-01 - binary_accuracy: 0.9893 - iou: 0.1527 - dice_coef: 0.2603 - val_loss: -2.6216e-01 - val_binary_accuracy: 0.9930 - val_iou: 0.1504 - val_dice_coef: 0.2567
#
# Epoch 00004: val_loss improved from -0.09338 to -0.26216, saving model to unet_brain_mri_seg.hdf5
# Epoch 5/100
# 88/88 - 198s - loss: -3.1849e-01 - binary_accuracy: 0.9916 - iou: 0.1913 - dice_coef: 0.3174 - val_loss: -3.5168e-01 - val_binary_accuracy: 0.9896 - val_iou: 0.2214 - val_dice_coef: 0.3552
#
# Epoch 00005: val_loss improved from -0.26216 to -0.35168, saving model to unet_brain_mri_seg.hdf5
# Epoch 6/100
# 88/88 - 198s - loss: -3.6686e-01 - binary_accuracy: 0.9925 - iou: 0.2277 - dice_coef: 0.3671 - val_loss: -4.2188e-01 - val_binary_accuracy: 0.9909 - val_iou: 0.2800 - val_dice_coef: 0.4314
#
# Epoch 00006: val_loss improved from -0.35168 to -0.42188, saving model to unet_brain_mri_seg.hdf5
# Epoch 7/100
# 88/88 - 197s - loss: -4.2835e-01 - binary_accuracy: 0.9935 - iou: 0.2768 - dice_coef: 0.4286 - val_loss: -4.8581e-01 - val_binary_accuracy: 0.9952 - val_iou: 0.3156 - val_dice_coef: 0.4686
#
# Epoch 00007: val_loss improved from -0.42188 to -0.48581, saving model to unet_brain_mri_seg.hdf5
# Epoch 8/100
# 88/88 - 197s - loss: -4.8847e-01 - binary_accuracy: 0.9943 - iou: 0.3284 - dice_coef: 0.4882 - val_loss: -4.8043e-01 - val_binary_accuracy: 0.9937 - val_iou: 0.3100 - val_dice_coef: 0.4631
#
# Epoch 00008: val_loss did not improve from -0.48581
# Epoch 9/100
# 88/88 - 197s - loss: -5.2213e-01 - binary_accuracy: 0.9943 - iou: 0.3596 - dice_coef: 0.5218 - val_loss: -5.6460e-01 - val_binary_accuracy: 0.9952 - val_iou: 0.4079 - val_dice_coef: 0.5732
#
# Epoch 00009: val_loss improved from -0.48581 to -0.56460, saving model to unet_brain_mri_seg.hdf5
# Epoch 10/100
# 88/88 - 197s - loss: -5.8519e-01 - binary_accuracy: 0.9952 - iou: 0.4206 - dice_coef: 0.5862 - val_loss: -6.0016e-01 - val_binary_accuracy: 0.9958 - val_iou: 0.4365 - val_dice_coef: 0.6024
#
# Epoch 00010: val_loss improved from -0.56460 to -0.60016, saving model to unet_brain_mri_seg.hdf5
# Epoch 11/100
# 88/88 - 197s - loss: -6.2061e-01 - binary_accuracy: 0.9955 - iou: 0.4580 - dice_coef: 0.6210 - val_loss: -5.8171e-01 - val_binary_accuracy: 0.9963 - val_iou: 0.4162 - val_dice_coef: 0.5757
#
# Epoch 00011: val_loss did not improve from -0.60016
# Epoch 12/100
# 88/88 - 197s - loss: -6.6429e-01 - binary_accuracy: 0.9960 - iou: 0.5047 - dice_coef: 0.6644 - val_loss: -6.8258e-01 - val_binary_accuracy: 0.9961 - val_iou: 0.5348 - val_dice_coef: 0.6903
#
# Epoch 00012: val_loss improved from -0.60016 to -0.68258, saving model to unet_brain_mri_seg.hdf5
# Epoch 13/100
# 88/88 - 197s - loss: -6.8246e-01 - binary_accuracy: 0.9959 - iou: 0.5239 - dice_coef: 0.6822 - val_loss: -7.0750e-01 - val_binary_accuracy: 0.9963 - val_iou: 0.5357 - val_dice_coef: 0.6849
#
# Epoch 00013: val_loss improved from -0.68258 to -0.70750, saving model to unet_brain_mri_seg.hdf5
# Epoch 14/100
# 88/88 - 196s - loss: -7.1875e-01 - binary_accuracy: 0.9964 - iou: 0.5671 - dice_coef: 0.7193 - val_loss: -7.4663e-01 - val_binary_accuracy: 0.9968 - val_iou: 0.6032 - val_dice_coef: 0.7486
#
# Epoch 00014: val_loss improved from -0.70750 to -0.74663, saving model to unet_brain_mri_seg.hdf5
# Epoch 15/100
# 88/88 - 197s - loss: -7.1682e-01 - binary_accuracy: 0.9963 - iou: 0.5689 - dice_coef: 0.7156 - val_loss: -7.4773e-01 - val_binary_accuracy: 0.9967 - val_iou: 0.6067 - val_dice_coef: 0.7498
#
# Epoch 00015: val_loss improved from -0.74663 to -0.74773, saving model to unet_brain_mri_seg.hdf5
# Epoch 16/100
# 88/88 - 197s - loss: -7.1314e-01 - binary_accuracy: 0.9959 - iou: 0.5631 - dice_coef: 0.7138 - val_loss: -7.1499e-01 - val_binary_accuracy: 0.9955 - val_iou: 0.5486 - val_dice_coef: 0.6948
#
# Epoch 00016: val_loss did not improve from -0.74773
# Epoch 17/100
# 88/88 - 196s - loss: -7.5720e-01 - binary_accuracy: 0.9965 - iou: 0.6140 - dice_coef: 0.7556 - val_loss: -7.8064e-01 - val_binary_accuracy: 0.9967 - val_iou: 0.6490 - val_dice_coef: 0.7843
#
# Epoch 00017: val_loss improved from -0.74773 to -0.78064, saving model to unet_brain_mri_seg.hdf5
# Epoch 18/100
# 88/88 - 196s - loss: -7.7538e-01 - binary_accuracy: 0.9967 - iou: 0.6384 - dice_coef: 0.7755 - val_loss: -7.7376e-01 - val_binary_accuracy: 0.9970 - val_iou: 0.6450 - val_dice_coef: 0.7797
#
# Epoch 00018: val_loss did not improve from -0.78064
# Epoch 19/100
# 88/88 - 196s - loss: -7.8828e-01 - binary_accuracy: 0.9968 - iou: 0.6545 - dice_coef: 0.7887 - val_loss: -8.0050e-01 - val_binary_accuracy: 0.9971 - val_iou: 0.6601 - val_dice_coef: 0.7912
#
# Epoch 00019: val_loss improved from -0.78064 to -0.80050, saving model to unet_brain_mri_seg.hdf5
# Epoch 20/100
# 88/88 - 196s - loss: -7.7826e-01 - binary_accuracy: 0.9965 - iou: 0.6432 - dice_coef: 0.7788 - val_loss: -7.9294e-01 - val_binary_accuracy: 0.9967 - val_iou: 0.6518 - val_dice_coef: 0.7759
#
# Epoch 00020: val_loss did not improve from -0.80050
# Epoch 21/100
# 88/88 - 196s - loss: -7.9857e-01 - binary_accuracy: 0.9969 - iou: 0.6715 - dice_coef: 0.7991 - val_loss: -8.1397e-01 - val_binary_accuracy: 0.9971 - val_iou: 0.6913 - val_dice_coef: 0.8145
#
# Epoch 00021: val_loss improved from -0.80050 to -0.81397, saving model to unet_brain_mri_seg.hdf5
# Epoch 22/100
# 88/88 - 196s - loss: -8.0128e-01 - binary_accuracy: 0.9969 - iou: 0.6739 - dice_coef: 0.8016 - val_loss: -8.2162e-01 - val_binary_accuracy: 0.9971 - val_iou: 0.6918 - val_dice_coef: 0.8121
#
# Epoch 00022: val_loss improved from -0.81397 to -0.82162, saving model to unet_brain_mri_seg.hdf5
# Epoch 23/100
# 88/88 - 196s - loss: -8.1957e-01 - binary_accuracy: 0.9971 - iou: 0.6970 - dice_coef: 0.8189 - val_loss: -8.2337e-01 - val_binary_accuracy: 0.9974 - val_iou: 0.6879 - val_dice_coef: 0.8003
#
# Epoch 00023: val_loss improved from -0.82162 to -0.82337, saving model to unet_brain_mri_seg.hdf5
# Epoch 24/100
# 88/88 - 196s - loss: -8.1808e-01 - binary_accuracy: 0.9971 - iou: 0.6979 - dice_coef: 0.8180 - val_loss: -8.1274e-01 - val_binary_accuracy: 0.9968 - val_iou: 0.6827 - val_dice_coef: 0.7990
#
# Epoch 00024: val_loss did not improve from -0.82337
# Epoch 25/100
# 88/88 - 196s - loss: -8.1677e-01 - binary_accuracy: 0.9971 - iou: 0.6960 - dice_coef: 0.8166 - val_loss: -8.2383e-01 - val_binary_accuracy: 0.9971 - val_iou: 0.6838 - val_dice_coef: 0.7946
#
# Epoch 00025: val_loss improved from -0.82337 to -0.82383, saving model to unet_brain_mri_seg.hdf5
# Epoch 26/100
# 88/88 - 196s - loss: -8.3530e-01 - binary_accuracy: 0.9973 - iou: 0.7215 - dice_coef: 0.8357 - val_loss: -8.3090e-01 - val_binary_accuracy: 0.9971 - val_iou: 0.7181 - val_dice_coef: 0.8331
#
# Epoch 00026: val_loss improved from -0.82383 to -0.83090, saving model to unet_brain_mri_seg.hdf5
# Epoch 27/100
# 88/88 - 196s - loss: -8.3744e-01 - binary_accuracy: 0.9973 - iou: 0.7245 - dice_coef: 0.8377 - val_loss: -8.3060e-01 - val_binary_accuracy: 0.9972 - val_iou: 0.7188 - val_dice_coef: 0.8346
#
# Epoch 00027: val_loss did not improve from -0.83090
# Epoch 28/100
# 88/88 - 196s - loss: -8.3284e-01 - binary_accuracy: 0.9971 - iou: 0.7176 - dice_coef: 0.8332 - val_loss: -8.1498e-01 - val_binary_accuracy: 0.9967 - val_iou: 0.6882 - val_dice_coef: 0.8027
#
# Epoch 00028: val_loss did not improve from -0.83090
# Epoch 29/100
# 88/88 - 196s - loss: -8.2400e-01 - binary_accuracy: 0.9971 - iou: 0.7070 - dice_coef: 0.8233 - val_loss: -8.4359e-01 - val_binary_accuracy: 0.9974 - val_iou: 0.7256 - val_dice_coef: 0.8313
#
# Epoch 00029: val_loss improved from -0.83090 to -0.84359, saving model to unet_brain_mri_seg.hdf5
# Epoch 30/100
# 88/88 - 196s - loss: -8.3892e-01 - binary_accuracy: 0.9973 - iou: 0.7270 - dice_coef: 0.8392 - val_loss: -8.4986e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7446 - val_dice_coef: 0.8510
#
# Epoch 00030: val_loss improved from -0.84359 to -0.84986, saving model to unet_brain_mri_seg.hdf5
# Epoch 31/100
# 88/88 - 196s - loss: -8.4180e-01 - binary_accuracy: 0.9972 - iou: 0.7318 - dice_coef: 0.8418 - val_loss: -8.5097e-01 - val_binary_accuracy: 0.9974 - val_iou: 0.7399 - val_dice_coef: 0.8414
#
# Epoch 00031: val_loss improved from -0.84986 to -0.85097, saving model to unet_brain_mri_seg.hdf5
# Epoch 32/100
# 88/88 - 196s - loss: -8.4945e-01 - binary_accuracy: 0.9973 - iou: 0.7409 - dice_coef: 0.8492 - val_loss: -8.5920e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7574 - val_dice_coef: 0.8610
#
# Epoch 00032: val_loss improved from -0.85097 to -0.85920, saving model to unet_brain_mri_seg.hdf5
# Epoch 33/100
# 88/88 - 196s - loss: -8.4990e-01 - binary_accuracy: 0.9974 - iou: 0.7446 - dice_coef: 0.8503 - val_loss: -8.4070e-01 - val_binary_accuracy: 0.9974 - val_iou: 0.7074 - val_dice_coef: 0.8119
#
# Epoch 00033: val_loss did not improve from -0.85920
# Epoch 34/100
# 88/88 - 196s - loss: -8.4203e-01 - binary_accuracy: 0.9972 - iou: 0.7330 - dice_coef: 0.8423 - val_loss: -8.4723e-01 - val_binary_accuracy: 0.9972 - val_iou: 0.7409 - val_dice_coef: 0.8491
#
# Epoch 00034: val_loss did not improve from -0.85920
# Epoch 35/100
# 88/88 - 196s - loss: -8.5147e-01 - binary_accuracy: 0.9973 - iou: 0.7445 - dice_coef: 0.8514 - val_loss: -8.6617e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7711 - val_dice_coef: 0.8689
#
# Epoch 00035: val_loss improved from -0.85920 to -0.86617, saving model to unet_brain_mri_seg.hdf5
# Epoch 36/100
# 88/88 - 196s - loss: -8.5273e-01 - binary_accuracy: 0.9974 - iou: 0.7484 - dice_coef: 0.8532 - val_loss: -8.4005e-01 - val_binary_accuracy: 0.9970 - val_iou: 0.7277 - val_dice_coef: 0.8347
#
# Epoch 00036: val_loss did not improve from -0.86617
# Epoch 37/100
# 88/88 - 196s - loss: -8.6219e-01 - binary_accuracy: 0.9975 - iou: 0.7611 - dice_coef: 0.8624 - val_loss: -8.6291e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7649 - val_dice_coef: 0.8646
#
# Epoch 00037: val_loss did not improve from -0.86617
# Epoch 38/100
# 88/88 - 196s - loss: -8.6330e-01 - binary_accuracy: 0.9976 - iou: 0.7633 - dice_coef: 0.8634 - val_loss: -8.6757e-01 - val_binary_accuracy: 0.9973 - val_iou: 0.7586 - val_dice_coef: 0.8518
#
# Epoch 00038: val_loss improved from -0.86617 to -0.86757, saving model to unet_brain_mri_seg.hdf5
# Epoch 39/100
# 88/88 - 196s - loss: -8.6010e-01 - binary_accuracy: 0.9975 - iou: 0.7592 - dice_coef: 0.8603 - val_loss: -8.5910e-01 - val_binary_accuracy: 0.9974 - val_iou: 0.7609 - val_dice_coef: 0.8625
#
# Epoch 00039: val_loss did not improve from -0.86757
# Epoch 40/100
# 88/88 - 196s - loss: -8.6688e-01 - binary_accuracy: 0.9976 - iou: 0.7667 - dice_coef: 0.8654 - val_loss: -8.6555e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7662 - val_dice_coef: 0.8604
#
# Epoch 00040: val_loss did not improve from -0.86757
# Epoch 41/100
# 88/88 - 196s - loss: -8.5408e-01 - binary_accuracy: 0.9974 - iou: 0.7485 - dice_coef: 0.8532 - val_loss: -8.6625e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7684 - val_dice_coef: 0.8673
#
# Epoch 00041: val_loss did not improve from -0.86757
# Epoch 42/100
# 88/88 - 196s - loss: -8.5370e-01 - binary_accuracy: 0.9974 - iou: 0.7515 - dice_coef: 0.8543 - val_loss: -8.6971e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7709 - val_dice_coef: 0.8685
#
# Epoch 00042: val_loss improved from -0.86757 to -0.86971, saving model to unet_brain_mri_seg.hdf5
# Epoch 43/100
# 88/88 - 196s - loss: -8.5829e-01 - binary_accuracy: 0.9975 - iou: 0.7572 - dice_coef: 0.8585 - val_loss: -8.6481e-01 - val_binary_accuracy: 0.9974 - val_iou: 0.7511 - val_dice_coef: 0.8538
#
# Epoch 00043: val_loss did not improve from -0.86971
# Epoch 44/100
# 88/88 - 196s - loss: -8.5181e-01 - binary_accuracy: 0.9973 - iou: 0.7480 - dice_coef: 0.8521 - val_loss: -8.8571e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.8021 - val_dice_coef: 0.8881
#
# Epoch 00044: val_loss improved from -0.86971 to -0.88571, saving model to unet_brain_mri_seg.hdf5
# Epoch 45/100
# 88/88 - 196s - loss: -8.6330e-01 - binary_accuracy: 0.9976 - iou: 0.7653 - dice_coef: 0.8639 - val_loss: -8.6599e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7693 - val_dice_coef: 0.8676
#
# Epoch 00045: val_loss did not improve from -0.88571
# Epoch 46/100
# 88/88 - 196s - loss: -8.6575e-01 - binary_accuracy: 0.9976 - iou: 0.7654 - dice_coef: 0.8600 - val_loss: -8.7140e-01 - val_binary_accuracy: 0.9974 - val_iou: 0.7748 - val_dice_coef: 0.8717
#
# Epoch 00046: val_loss did not improve from -0.88571
# Epoch 47/100
# 88/88 - 196s - loss: -8.7027e-01 - binary_accuracy: 0.9976 - iou: 0.7738 - dice_coef: 0.8707 - val_loss: -8.6617e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.7727 - val_dice_coef: 0.8683
#
# Epoch 00047: val_loss did not improve from -0.88571
# Epoch 48/100
# 88/88 - 196s - loss: -8.6815e-01 - binary_accuracy: 0.9976 - iou: 0.7693 - dice_coef: 0.8669 - val_loss: -8.7337e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.7802 - val_dice_coef: 0.8711
#
# Epoch 00048: val_loss did not improve from -0.88571
# Epoch 49/100
# 88/88 - 196s - loss: -8.7598e-01 - binary_accuracy: 0.9977 - iou: 0.7827 - dice_coef: 0.8764 - val_loss: -8.7234e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.7551 - val_dice_coef: 0.8446
#
# Epoch 00049: val_loss did not improve from -0.88571
# Epoch 50/100
# 88/88 - 196s - loss: -8.7626e-01 - binary_accuracy: 0.9977 - iou: 0.7825 - dice_coef: 0.8765 - val_loss: -8.6962e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.7781 - val_dice_coef: 0.8690
#
# Epoch 00050: val_loss did not improve from -0.88571
# Epoch 51/100
# 88/88 - 196s - loss: -8.7022e-01 - binary_accuracy: 0.9976 - iou: 0.7751 - dice_coef: 0.8706 - val_loss: -8.7984e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.7726 - val_dice_coef: 0.8666
#
# Epoch 00051: val_loss did not improve from -0.88571
# Epoch 52/100
# 88/88 - 196s - loss: -8.7385e-01 - binary_accuracy: 0.9977 - iou: 0.7793 - dice_coef: 0.8738 - val_loss: -8.8994e-01 - val_binary_accuracy: 0.9981 - val_iou: 0.7937 - val_dice_coef: 0.8812
#
# Epoch 00052: val_loss improved from -0.88571 to -0.88994, saving model to unet_brain_mri_seg.hdf5
# Epoch 53/100
# 88/88 - 196s - loss: -8.6674e-01 - binary_accuracy: 0.9976 - iou: 0.7717 - dice_coef: 0.8671 - val_loss: -8.7808e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.7851 - val_dice_coef: 0.8768
#
# Epoch 00053: val_loss did not improve from -0.88994
# Epoch 54/100
# 88/88 - 196s - loss: -8.6233e-01 - binary_accuracy: 0.9975 - iou: 0.7640 - dice_coef: 0.8626 - val_loss: -8.6518e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7488 - val_dice_coef: 0.8419
#
# Epoch 00054: val_loss did not improve from -0.88994
# Epoch 55/100
# 88/88 - 196s - loss: -8.7539e-01 - binary_accuracy: 0.9977 - iou: 0.7821 - dice_coef: 0.8759 - val_loss: -8.7168e-01 - val_binary_accuracy: 0.9979 - val_iou: 0.7706 - val_dice_coef: 0.8601
#
# Epoch 00055: val_loss did not improve from -0.88994
# Epoch 56/100
# 88/88 - 196s - loss: -8.8084e-01 - binary_accuracy: 0.9978 - iou: 0.7899 - dice_coef: 0.8809 - val_loss: -8.7500e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.7821 - val_dice_coef: 0.8760
#
# Epoch 00056: val_loss did not improve from -0.88994
# Epoch 57/100
# 88/88 - 196s - loss: -8.7995e-01 - binary_accuracy: 0.9978 - iou: 0.7866 - dice_coef: 0.8784 - val_loss: -8.7186e-01 - val_binary_accuracy: 0.9974 - val_iou: 0.7720 - val_dice_coef: 0.8686
#
# Epoch 00057: val_loss did not improve from -0.88994
# Epoch 58/100
# 88/88 - 196s - loss: -8.2309e-01 - binary_accuracy: 0.9968 - iou: 0.7075 - dice_coef: 0.8232 - val_loss: -8.6744e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7730 - val_dice_coef: 0.8695
#
# Epoch 00058: val_loss did not improve from -0.88994
# Epoch 59/100
# 88/88 - 196s - loss: -8.7287e-01 - binary_accuracy: 0.9976 - iou: 0.7775 - dice_coef: 0.8729 - val_loss: -8.6203e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7666 - val_dice_coef: 0.8632
#
# Epoch 00059: val_loss did not improve from -0.88994
# Epoch 60/100
# 88/88 - 196s - loss: -8.6641e-01 - binary_accuracy: 0.9975 - iou: 0.7695 - dice_coef: 0.8668 - val_loss: -8.7636e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.7833 - val_dice_coef: 0.8768
#
# Epoch 00060: val_loss did not improve from -0.88994
# Epoch 61/100
# 88/88 - 196s - loss: -8.7880e-01 - binary_accuracy: 0.9978 - iou: 0.7880 - dice_coef: 0.8790 - val_loss: -8.8108e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.7922 - val_dice_coef: 0.8822
#
# Epoch 00061: val_loss did not improve from -0.88994
# Epoch 62/100
# 88/88 - 196s - loss: -8.8330e-01 - binary_accuracy: 0.9978 - iou: 0.7924 - dice_coef: 0.8825 - val_loss: -8.8871e-01 - val_binary_accuracy: 0.9979 - val_iou: 0.8064 - val_dice_coef: 0.8894
#
# Epoch 00062: val_loss did not improve from -0.88994
# Epoch 63/100
# 88/88 - 196s - loss: -8.8727e-01 - binary_accuracy: 0.9978 - iou: 0.7986 - dice_coef: 0.8863 - val_loss: -8.7186e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.7820 - val_dice_coef: 0.8753
#
# Epoch 00063: val_loss did not improve from -0.88994
# Epoch 64/100
# 88/88 - 196s - loss: -8.8371e-01 - binary_accuracy: 0.9978 - iou: 0.7937 - dice_coef: 0.8826 - val_loss: -8.8789e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.8060 - val_dice_coef: 0.8895
#
# Epoch 00064: val_loss did not improve from -0.88994
# Epoch 65/100
# 88/88 - 196s - loss: -8.8613e-01 - binary_accuracy: 0.9979 - iou: 0.7988 - dice_coef: 0.8862 - val_loss: -8.8489e-01 - val_binary_accuracy: 0.9979 - val_iou: 0.8010 - val_dice_coef: 0.8861
#
# Epoch 00065: val_loss did not improve from -0.88994
# Epoch 66/100
# 88/88 - 196s - loss: -8.8802e-01 - binary_accuracy: 0.9979 - iou: 0.8016 - dice_coef: 0.8882 - val_loss: -8.8091e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.7877 - val_dice_coef: 0.8789
#
# Epoch 00066: val_loss did not improve from -0.88994
# Epoch 67/100
# 88/88 - 196s - loss: -8.8600e-01 - binary_accuracy: 0.9979 - iou: 0.7978 - dice_coef: 0.8856 - val_loss: -8.9413e-01 - val_binary_accuracy: 0.9979 - val_iou: 0.8153 - val_dice_coef: 0.8957
#
# Epoch 00067: val_loss improved from -0.88994 to -0.89413, saving model to unet_brain_mri_seg.hdf5
# Epoch 68/100
# 88/88 - 196s - loss: -8.8719e-01 - binary_accuracy: 0.9979 - iou: 0.7990 - dice_coef: 0.8865 - val_loss: -8.8635e-01 - val_binary_accuracy: 0.9979 - val_iou: 0.7997 - val_dice_coef: 0.8873
#
# Epoch 00068: val_loss did not improve from -0.89413
# Epoch 69/100
# 88/88 - 196s - loss: -8.8042e-01 - binary_accuracy: 0.9978 - iou: 0.7905 - dice_coef: 0.8804 - val_loss: -8.8488e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.7998 - val_dice_coef: 0.8874
#
# Epoch 00069: val_loss did not improve from -0.89413
# Epoch 70/100
# 88/88 - 196s - loss: -8.8055e-01 - binary_accuracy: 0.9977 - iou: 0.7902 - dice_coef: 0.8808 - val_loss: -8.7652e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7792 - val_dice_coef: 0.8743
#
# Epoch 00070: val_loss did not improve from -0.89413
# Epoch 71/100
# 88/88 - 196s - loss: -8.6408e-01 - binary_accuracy: 0.9975 - iou: 0.7646 - dice_coef: 0.8634 - val_loss: -8.7306e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7752 - val_dice_coef: 0.8716
#
# Epoch 00071: val_loss did not improve from -0.89413
# Epoch 72/100
# 88/88 - 196s - loss: -8.6838e-01 - binary_accuracy: 0.9976 - iou: 0.7723 - dice_coef: 0.8686 - val_loss: -8.6418e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7693 - val_dice_coef: 0.8670
#
# Epoch 00072: val_loss did not improve from -0.89413
# Epoch 73/100
# 88/88 - 196s - loss: -8.7245e-01 - binary_accuracy: 0.9976 - iou: 0.7772 - dice_coef: 0.8721 - val_loss: -8.5014e-01 - val_binary_accuracy: 0.9971 - val_iou: 0.7440 - val_dice_coef: 0.8497
#
# Epoch 00073: val_loss did not improve from -0.89413
# Epoch 74/100
# 88/88 - 196s - loss: -8.7230e-01 - binary_accuracy: 0.9976 - iou: 0.7741 - dice_coef: 0.8691 - val_loss: -8.6595e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7744 - val_dice_coef: 0.8695
#
# Epoch 00074: val_loss did not improve from -0.89413
# Epoch 75/100
# 88/88 - 196s - loss: -8.8125e-01 - binary_accuracy: 0.9978 - iou: 0.7922 - dice_coef: 0.8818 - val_loss: -8.7717e-01 - val_binary_accuracy: 0.9979 - val_iou: 0.7853 - val_dice_coef: 0.8766
#
# Epoch 00075: val_loss did not improve from -0.89413
# Epoch 76/100
# 88/88 - 196s - loss: -8.7995e-01 - binary_accuracy: 0.9978 - iou: 0.7885 - dice_coef: 0.8798 - val_loss: -8.8556e-01 - val_binary_accuracy: 0.9979 - val_iou: 0.7843 - val_dice_coef: 0.8748
#
# Epoch 00076: val_loss did not improve from -0.89413
# Epoch 77/100
# 88/88 - 196s - loss: -8.8233e-01 - binary_accuracy: 0.9978 - iou: 0.7932 - dice_coef: 0.8826 - val_loss: -8.8612e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.8015 - val_dice_coef: 0.8885
#
# Epoch 00077: val_loss did not improve from -0.89413
# Epoch 78/100
# 88/88 - 196s - loss: -8.8676e-01 - binary_accuracy: 0.9979 - iou: 0.8010 - dice_coef: 0.8871 - val_loss: -8.8262e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.7984 - val_dice_coef: 0.8857
#
# Epoch 00078: val_loss did not improve from -0.89413
# Epoch 79/100
# 88/88 - 196s - loss: -8.8939e-01 - binary_accuracy: 0.9979 - iou: 0.8043 - dice_coef: 0.8898 - val_loss: -8.8166e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7867 - val_dice_coef: 0.8784
#
# Epoch 00079: val_loss did not improve from -0.89413
# Epoch 80/100
# 88/88 - 196s - loss: -8.7517e-01 - binary_accuracy: 0.9977 - iou: 0.7802 - dice_coef: 0.8711 - val_loss: -7.8797e-01 - val_binary_accuracy: 0.9964 - val_iou: 0.6673 - val_dice_coef: 0.7937
#
# Epoch 00080: val_loss did not improve from -0.89413
# Epoch 81/100
# 88/88 - 196s - loss: -8.3756e-01 - binary_accuracy: 0.9971 - iou: 0.7300 - dice_coef: 0.8381 - val_loss: -8.5314e-01 - val_binary_accuracy: 0.9972 - val_iou: 0.7537 - val_dice_coef: 0.8574
#
# Epoch 00081: val_loss did not improve from -0.89413
# Epoch 82/100
# 88/88 - 196s - loss: -8.7390e-01 - binary_accuracy: 0.9977 - iou: 0.7810 - dice_coef: 0.8743 - val_loss: -8.7843e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7894 - val_dice_coef: 0.8810
#
# Epoch 00082: val_loss did not improve from -0.89413
# Epoch 83/100
# 88/88 - 196s - loss: -8.8908e-01 - binary_accuracy: 0.9979 - iou: 0.8033 - dice_coef: 0.8895 - val_loss: -8.6980e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7766 - val_dice_coef: 0.8724
#
# Epoch 00083: val_loss did not improve from -0.89413
# Epoch 84/100
# 88/88 - 196s - loss: -8.8018e-01 - binary_accuracy: 0.9977 - iou: 0.7895 - dice_coef: 0.8803 - val_loss: -8.8426e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.7984 - val_dice_coef: 0.8865
#
# Epoch 00084: val_loss did not improve from -0.89413
# Epoch 85/100
# 88/88 - 196s - loss: -8.8381e-01 - binary_accuracy: 0.9978 - iou: 0.7939 - dice_coef: 0.8829 - val_loss: -8.5983e-01 - val_binary_accuracy: 0.9974 - val_iou: 0.7517 - val_dice_coef: 0.8562
#
# Epoch 00085: val_loss did not improve from -0.89413
# Epoch 86/100
# 88/88 - 196s - loss: -8.8514e-01 - binary_accuracy: 0.9978 - iou: 0.7980 - dice_coef: 0.8855 - val_loss: -8.9424e-01 - val_binary_accuracy: 0.9980 - val_iou: 0.7909 - val_dice_coef: 0.8728
#
# Epoch 00086: val_loss improved from -0.89413 to -0.89424, saving model to unet_brain_mri_seg.hdf5
# Epoch 87/100
# 88/88 - 196s - loss: -8.9270e-01 - binary_accuracy: 0.9980 - iou: 0.8090 - dice_coef: 0.8928 - val_loss: -8.8744e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.7983 - val_dice_coef: 0.8860
#
# Epoch 00087: val_loss did not improve from -0.89424
# Epoch 88/100
# 88/88 - 196s - loss: -8.8837e-01 - binary_accuracy: 0.9979 - iou: 0.8027 - dice_coef: 0.8888 - val_loss: -8.7899e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7909 - val_dice_coef: 0.8819
#
# Epoch 00088: val_loss did not improve from -0.89424
# Epoch 89/100
# 88/88 - 196s - loss: -8.8464e-01 - binary_accuracy: 0.9978 - iou: 0.7959 - dice_coef: 0.8850 - val_loss: -8.7858e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.7915 - val_dice_coef: 0.8807
#
# Epoch 00089: val_loss did not improve from -0.89424
# Epoch 90/100
# 88/88 - 196s - loss: -8.8456e-01 - binary_accuracy: 0.9978 - iou: 0.7939 - dice_coef: 0.8827 - val_loss: -8.7210e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7798 - val_dice_coef: 0.8737
#
# Epoch 00090: val_loss did not improve from -0.89424
# Epoch 91/100
# 88/88 - 196s - loss: -8.7316e-01 - binary_accuracy: 0.9976 - iou: 0.7802 - dice_coef: 0.8735 - val_loss: -8.7972e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7914 - val_dice_coef: 0.8824
#
# Epoch 00091: val_loss did not improve from -0.89424
# Epoch 92/100
# 88/88 - 196s - loss: -8.8126e-01 - binary_accuracy: 0.9978 - iou: 0.7913 - dice_coef: 0.8806 - val_loss: -8.7772e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7848 - val_dice_coef: 0.8770
#
# Epoch 00092: val_loss did not improve from -0.89424
# Epoch 93/100
# 88/88 - 196s - loss: -8.7207e-01 - binary_accuracy: 0.9976 - iou: 0.7790 - dice_coef: 0.8721 - val_loss: -8.7682e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.7849 - val_dice_coef: 0.8772
#
# Epoch 00093: val_loss did not improve from -0.89424
# Epoch 94/100
# 88/88 - 196s - loss: -8.8850e-01 - binary_accuracy: 0.9979 - iou: 0.8019 - dice_coef: 0.8885 - val_loss: -8.8655e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.8050 - val_dice_coef: 0.8895
#
# Epoch 00094: val_loss did not improve from -0.89424
# Epoch 95/100
# 88/88 - 196s - loss: -8.8654e-01 - binary_accuracy: 0.9979 - iou: 0.7996 - dice_coef: 0.8851 - val_loss: -8.8375e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.8012 - val_dice_coef: 0.8875
#
# Epoch 00095: val_loss did not improve from -0.89424
# Epoch 96/100
# 88/88 - 196s - loss: -8.8955e-01 - binary_accuracy: 0.9979 - iou: 0.8045 - dice_coef: 0.8896 - val_loss: -8.8247e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.7922 - val_dice_coef: 0.8811
#
# Epoch 00096: val_loss did not improve from -0.89424
# Epoch 97/100
# 88/88 - 196s - loss: -8.9661e-01 - binary_accuracy: 0.9980 - iou: 0.8154 - dice_coef: 0.8967 - val_loss: -8.7220e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.7784 - val_dice_coef: 0.8730
#
# Epoch 00097: val_loss did not improve from -0.89424
# Epoch 98/100
# 88/88 - 196s - loss: -8.9712e-01 - binary_accuracy: 0.9980 - iou: 0.8148 - dice_coef: 0.8963 - val_loss: -8.9496e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.8181 - val_dice_coef: 0.8981
#
# Epoch 00098: val_loss improved from -0.89424 to -0.89496, saving model to unet_brain_mri_seg.hdf5
# Epoch 99/100
# 88/88 - 196s - loss: -8.8991e-01 - binary_accuracy: 0.9980 - iou: 0.8060 - dice_coef: 0.8899 - val_loss: -8.7804e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7848 - val_dice_coef: 0.8776
#
# Epoch 00099: val_loss did not improve from -0.89496
# Epoch 100/100
# 88/88 - 196s - loss: -8.9868e-01 - binary_accuracy: 0.9980 - iou: 0.8182 - dice_coef: 0.8989 - val_loss: -8.8883e-01 - val_binary_accuracy: 0.9979 - val_iou: 0.8096 - val_dice_coef: 0.8925
#
# Epoch 00100: val_loss did not improve from -0.89496

# %%
a = history.history

list_traindice = a['dice_coef']
list_testdice = a['val_dice_coef']

list_trainjaccard = a['iou']
list_testjaccard = a['val_iou']

list_trainloss = a['loss']
list_testloss = a['val_loss']
plt.figure(1)
plt.plot(list_testloss, 'b-')
plt.plot(list_trainloss,'r-')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.title('loss graph', fontsize = 15)
plt.figure(2)
plt.plot(list_traindice, 'r-')
plt.plot(list_testdice, 'b-')
plt.xlabel('iteration')
plt.ylabel('accuracy')
plt.title('accuracy graph', fontsize = 15)
plt.show()

# %%
test_gen = train_generator(df_test, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))
model.compile(optimizer=opt, loss=dice_coef_loss, metrics=["binary_accuracy", iou, dice_coef])
results = model.evaluate(test_gen, steps=len(df_test) / BATCH_SIZE)
print("Test lost: ",results[0])
print("Test IOU: ",results[1])
print("Test Dice Coefficent: ",results[2])
# Out:
# Found 393 validated image filenames.
# Found 393 validated image filenames.
# 12/12 [==============================] - 12s 822ms/step - loss: -0.8958 - binary_accuracy: 0.9977 - iou: 0.8138 - dice_coef: 0.8949
# Test lost:  -0.8842145204544067
# Test IOU:  0.9976337552070618
# Test Dice Coefficent:  0.7892439961433411

# %%
for i in range(30):
    index=np.random.randint(1,len(df_test.index))
    img = cv2.imread(df_test['filename'].iloc[index])
    img = cv2.resize(img ,(im_height, im_width))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.imread(df_test['mask'].iloc[index])))
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()
